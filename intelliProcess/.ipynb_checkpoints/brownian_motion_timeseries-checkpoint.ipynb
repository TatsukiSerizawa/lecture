# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#標準正規分布（平均0, 標準偏差1を64個作成）
score0 = np.random.normal(0, 1, 64)
score1 = np.random.normal(0, 1, 64)
score2 = np.random.normal(0, 1, 64)
score3 = np.random.normal(0, 1, 64)
score4 = np.random.normal(0, 1, 64)

print(score0)
# Out:
# [-3.88205145e-01 -6.16517393e-01 -4.82686435e-01  2.85126688e-01
#   4.35106551e-01 -3.58243834e-01  1.12848158e+00  2.00132211e+00
#  -3.53672225e-01 -1.89834543e+00 -8.19454470e-01  1.39141802e+00
#  -7.59318058e-01 -1.69099713e+00 -2.33690186e+00 -5.00095483e-01
#  -2.21558525e-01  1.06116105e-01  5.04285064e-04  7.34618815e-01
#  -4.82763376e-01 -2.70293407e-01 -6.01956486e-01 -1.93691830e-01
#   1.22849195e+00 -7.97078317e-01 -3.43334739e-01  1.19330489e+00
#   5.12903840e-01  1.05820495e+00  6.29620881e-01  1.07297833e+00
#  -1.38266376e+00 -9.45191659e-01  1.70786136e+00  5.02615782e-01
#   9.02088439e-01  2.42436228e+00 -1.46879009e-01 -8.09713219e-01
#   1.00022955e+00 -1.32437498e-01  1.10379329e+00  4.31320931e-01
#   4.49440150e-02  8.55646844e-01  3.39815304e-01 -1.16275183e+00
#  -4.14538124e-01 -4.22684155e-01  1.09632144e+00 -1.02320685e-01
#   2.05060975e-01 -3.80472397e-02 -6.18259144e-01 -8.77792179e-01
#  -3.13924851e-01  4.58655450e-01 -1.25123538e+00  2.05789298e-01
#   5.85250231e-01  7.57346979e-01 -4.54454185e-02 -9.54997655e-01]

# %%
plt.hist(score0, bins=10)
plt.xlim(-5,5)
# Out:
# (-5, 5)

# %%
for i in range(64):
    if i==0:
        continue
    else:
        score0[i] += score0[i-1]
        score1[i] += score1[i-1]
        score2[i] += score2[i-1]
        score3[i] += score3[i-1]
        score4[i] += score4[i-1]
print(score0)
# Out:
# [-3.88205145e-01 -1.00472254e+00 -1.48740897e+00 -1.20228228e+00
#  -7.67175733e-01 -1.12541957e+00  3.06201357e-03  2.00438412e+00
#   1.65071190e+00 -2.47633531e-01 -1.06708800e+00  3.24330017e-01
#  -4.34988041e-01 -2.12598517e+00 -4.46288704e+00 -4.96298252e+00
#  -5.18454104e+00 -5.07842494e+00 -5.07792065e+00 -4.34330184e+00
#  -4.82606521e+00 -5.09635862e+00 -5.69831511e+00 -5.89200694e+00
#  -4.66351499e+00 -5.46059330e+00 -5.80392804e+00 -4.61062316e+00
#  -4.09771932e+00 -3.03951436e+00 -2.40989348e+00 -1.33691515e+00
#  -2.71957891e+00 -3.66477057e+00 -1.95690921e+00 -1.45429343e+00
#  -5.52204988e-01  1.87215729e+00  1.72527829e+00  9.15565066e-01
#   1.91579461e+00  1.78335712e+00  2.88715040e+00  3.31847134e+00
#   3.36341535e+00  4.21906219e+00  4.55887750e+00  3.39612567e+00
#   2.98158755e+00  2.55890339e+00  3.65522483e+00  3.55290415e+00
#   3.75796512e+00  3.71991788e+00  3.10165874e+00  2.22386656e+00
#   1.90994171e+00  2.36859716e+00  1.11736178e+00  1.32315107e+00
#   1.90840130e+00  2.66574828e+00  2.62030286e+00  1.66530521e+00]

# %%
sns.set()
plt.plot(score0, label='score0')
plt.plot(score1, label='score1')
plt.plot(score2, label='score2')
plt.plot(score3, label='score3')
plt.plot(score4, label='score4')

#グラフの軸
plt.xlabel('TIME')
plt.ylabel('Score')
#グラフの凡例
plt.legend()

plt.show()

# %%
print(score0[0], '\t', score0[63], '\t差分：', score0[63]-score0[0])
print(score1[0], '\t', score1[63], '\t差分：', score1[63]-score1[0])
print(score2[0], '\t', score2[63], '\t差分：', score2[63]-score2[0])
print(score3[0], '\t', score3[63], '\t差分：', score3[63]-score3[0])
print(score4[0], '\t', score4[63], '\t差分：', score4[63]-score4[0])
# Out:
# -0.3882051448547921 	 1.6653052096173608 	差分： 2.053510354472153
# -0.5643095979607051 	 -1.1192139928685625 	差分： -0.5549043949078574
# -1.1438418103098327 	 -7.840304130315342 	差分： -6.69646232000551
# -0.3458502396284667 	 -11.400397463708817 	差分： -11.05454722408035
# 1.0809811177029727 	 -5.213582294450598 	差分： -6.29456341215357

# %%
plt.plot(score0, label='score0')
#グラフの軸
plt.xlabel('TIME')
plt.ylabel('Score')
plt.xticks(np.arange(0-1, 64+1, 7))
plt.yticks(np.arange(-6-0.5, 5, 1.6))

plt.show()

# %%
plt.plot(score0, label='score0')
#グラフの軸
#plt.xlabel('TIME')
#plt.ylabel('Score')
plt.xticks(np.arange(0-1, 64+1, 4.5))
plt.yticks(np.arange(-6-0.5, 5, 1))

plt.show()
